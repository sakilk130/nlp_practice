# %% [markdown]
# ## 1.3 Regular Expressions
#
# ### What are Regular Expressions?
# Regular expressions (regex) are powerful patterns used to match, search, and manipulate text. They provide a concise way to describe complex string patterns.
#
# ### Why Use Regex in NLP?
# - **Text Cleaning**: Remove unwanted characters, normalize text
# - **Pattern Matching**: Find specific formats (emails, URLs, phone numbers)
# - **Tokenization**: Split text based on patterns
# - **Data Extraction**: Pull structured information from unstructured text
#
# ### Basic Regex Patterns
# - `.` - Any single character
# - `*` - Zero or more of the preceding element
# - `+` - One or more of the preceding element
# - `?` - Zero or one of the preceding element
# - `^` - Start of string
# - `$` - End of string
# - `[abc]` - Any character in the set
# - `[^abc]` - Any character not in the set
# - `\d` - Any digit (0-9)
# - `\w` - Any word character (alphanumeric + underscore)
# - `\s` - Any whitespace character
#
# ### Common NLP Regex Examples
# - **Email**: `r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'`
# - **URL**: `r'https?://(?:[-\w.])+(?:[:\d]+)?(?:/(?:[\w/_.])*(?:\?(?:[\w&=%.])*)?(?:#(?:\w*))*)?'`
# - **Phone Number**: `r'\(?\d{3}\)?-?\d{3}-?\d{4}'`
# - **Hashtags**: `r'#\w+'`
# - **Mentions**: `r'@\w+'`
#
# ### Python Regex Module
# Use the `re` module for regex operations:
# - `re.search()` - Find first match
# - `re.findall()` - Find all matches
# - `re.sub()` - Replace matches
# - `re.split()` - Split by pattern

# %%
import re

# %%
# print text without using raw string indicator
my_folder = "C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop
# otes
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/ll/jc6zxxdd0d11gx258tqz2x8m0000gn/T/ipykernel_68787/1154894801.py:2: SyntaxWarning: invalid escape sequence '\d'
#   my_folder = "C:\desktop\notes"

# %%
# include raw string indicator
my_folder = r"C:\desktop\notes"
print(my_folder)
# Out:
# C:\desktop\notes

# %%
# re.search
result_search = re.search("pattern", r"string containing the pattern")
print(result_search)
# Out:
# <re.Match object; span=(22, 29), match='pattern'>

# %%
print(result_search.group()) # returns just the matching pattern
# Out:
# pattern

# %%
string = r"sara was able to help me find the items i needed quickly"

# %%
# replace the incorrect spelling of sarah
new_string = re.sub(r"sara", r"sarah", string) # replace the incorrect spelling of sarah
print(new_string)
# Out:
# sarah was able to help me find the items i needed quickly

# %% [markdown]
# ### Regex Syntax

# %%
customer_reviews = ['sam was a great help to me in the store', 
                    'the cashier was very rude to me, I think her name was eleanor', 
                    'amazing work from sadeen!', 
                    'sarah was able to help me find the items i needed quickly', 
                    'lucy is such a great addition to the team', 
                    'great service from sara she found me what i wanted'
                    ]

# %%
# find sarahs review 
sarahs_reviews = []
pattern_to_find = r"sarah?" 

for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        sarahs_reviews.append(string)
print(sarahs_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
# Find reviews that start with the letter a
a_reviews = []
pattern_to_find = r"^a"

for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        a_reviews.append(string)
print(a_reviews)
# Out:
# ['amazing work from sadeen!']

# %%
# Find reviews that end with the letter y
y_reviews = []
pattern_to_find = r"y$"

for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        y_reviews.append(string)
print(y_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly']

# %%
# Find reviews that contain the words needed or wanted
needwant_reviews = []
pattern_to_find = r"(need|want)ed"

for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        needwant_reviews.append(string)

print(needwant_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
# Remove anything from the review that isn't a word or a space 
no_punct_reviews = []
pattern_to_find = r"[^\w\s]" 
for string in customer_reviews:
    no_punct_string = re.sub(pattern_to_find, "", string)
    no_punct_reviews.append(no_punct_string)
print(no_punct_reviews)
# Out:
# ['sam was a great help to me in the store', 'the cashier was very rude to me I think her name was eleanor', 'amazing work from sadeen', 'sarah was able to help me find the items i needed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted']
